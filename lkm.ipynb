# %% [markdown]
# # Lukumääriä ja prosentteja

# %%
import pandas as pd
df = pd.read_excel('http://www.elisanet.fi/taanila/data1.xlsx', sheet_name = 'Data')
df.head()
# Out:
#    nro  sukupuoli  ikä  perhe  koulutus  palvelusvuodet  palkka  \
# 0    1          1   38      1       1.0            22.0    3587
# 1    2          1   29      2       2.0            10.0    2963
# 2    3          1   30      1       1.0             7.0    1989
# 3    4          1   36      2       1.0            14.0    2144
# 4    5          1   24      1       2.0             4.0    2183
#
#    tyytyväisyys johtoon  tyytyväisyys työtovereihin  \
# 0                     3                         3.0
# 1                     1                         5.0
# 2                     3                         4.0
# 3                     3                         3.0
# 4                     2                         3.0
#
#    tyytyväisyys työympäristöön  tyytyväisyys palkkaan  \
# 0                            3                      3
# 1                            2                      1
# 2                            1                      1
# 3                            3                      3
# 4                            2                      1
#
#    tyytyväisyys työtehtäviin  työterveyshuolto  lomaosake  kuntosali  hieroja
# 0                          3               NaN        NaN        NaN      NaN
# 1                          3               NaN        NaN        NaN      NaN
# 2                          3               1.0        NaN        NaN      NaN
# 3                          3               1.0        NaN        NaN      NaN
# 4                          2               1.0        NaN        NaN      NaN

# %%
#frekvenssit value_counts-funktiolla
df1 = df['koulutus'].value_counts(sort = False).to_frame()
df1.index = ['peruskoulu','2.aste','korkeakoulu','ylempi korkeakoulu']
df1
# Out:
#                     koulutus
# peruskoulu                27
# 2.aste                    30
# korkeakoulu               22
# ylempi korkeakoulu         2

# %%
#prosentit frekvenssien viereen
df1 = df1.rename(columns = {'koulutus': 'lkm'})
df1['%'] = df1['lkm'] / df1['lkm'].sum() * 100
df1
# Out:
#                     lkm          %
# peruskoulu           27  33.333333
# 2.aste               30  37.037037
# korkeakoulu          22  27.160494
# ylempi korkeakoulu    2   2.469136

# %%
#kertymäprosentit ja pyöristys yhteen desimaaliin
df1['kertymä %'] = df1['%'].cumsum().round(decimals = 1)
df1['%'] = df1['%'].round(decimals = 1)
df1
# Out:
#                     lkm     %  kertymä %
# peruskoulu           27  33.3       33.3
# 2.aste               30  37.0       70.4
# korkeakoulu          22  27.2       97.5
# ylempi korkeakoulu    2   2.5      100.0

# %%
#crosstab-funktio on vaihtoehtoinen tapa frekvenssien laskemiseen
#crosstabin etu on, että se tuottaa suoraan dataframen
df2 = pd.crosstab(df['koulutus'], 'lkm')
df2.index = ['peruskoulu','2.aste','korkeakoulu','ylempi korkeakoulu']
df2.columns.name = '' #poistaa häiritsevän col_0 -otsikon taulukon oikeasta yläkulmasta
df2
# Out:
#                     lkm
# peruskoulu           27
# 2.aste               30
# korkeakoulu          22
# ylempi korkeakoulu    2

# %%
#prosentit frekvenssien viereen
df2['%'] = df2['lkm'] / df2['lkm'].sum()
df2
# Out:
#                     lkm         %
# peruskoulu           27  0.333333
# 2.aste               30  0.370370
# korkeakoulu          22  0.271605
# ylempi korkeakoulu    2  0.024691

# %%
#kertymäprosentit ja prosenttien tyylittely
df2['kertymä %'] = df2['%'].cumsum()
df2.style.format({'%': '{:,.1%}', 'kertymä %': '{:,.1%}'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_afdfc29a_9677_11e8_af9a_00e18c75b321" >
# <thead>    <tr>
#         <th class="index_name level0" ></th>
#         <th class="col_heading level0 col0" >lkm</th>
#         <th class="col_heading level0 col1" >%</th>
#         <th class="col_heading level0 col2" >kertymä %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_afdfc29a_9677_11e8_af9a_00e18c75b321level0_row0" class="row_heading level0 row0" >peruskoulu</th>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row0_col0" class="data row0 col0" >27</td>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row0_col1" class="data row0 col1" >33.3%</td>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row0_col2" class="data row0 col2" >33.3%</td>
#     </tr>    <tr>
#         <th id="T_afdfc29a_9677_11e8_af9a_00e18c75b321level0_row1" class="row_heading level0 row1" >2.aste</th>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row1_col0" class="data row1 col0" >30</td>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row1_col1" class="data row1 col1" >37.0%</td>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row1_col2" class="data row1 col2" >70.4%</td>
#     </tr>    <tr>
#         <th id="T_afdfc29a_9677_11e8_af9a_00e18c75b321level0_row2" class="row_heading level0 row2" >korkeakoulu</th>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row2_col0" class="data row2 col0" >22</td>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row2_col1" class="data row2 col1" >27.2%</td>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row2_col2" class="data row2 col2" >97.5%</td>
#     </tr>    <tr>
#         <th id="T_afdfc29a_9677_11e8_af9a_00e18c75b321level0_row3" class="row_heading level0 row3" >ylempi korkeakoulu</th>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row3_col0" class="data row3 col0" >2</td>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row3_col1" class="data row3 col1" >2.5%</td>
#         <td id="T_afdfc29a_9677_11e8_af9a_00e18c75b321row3_col2" class="data row3 col2" >100.0%</td>
#     </tr></tbody>
# </table>

# %%
#ikäluokkien frekvenssit
df3 = df['ikä'].value_counts(sort = False, bins = [18,29,39,49,59,69]).to_frame()
df3
# Out:
#                 ikä
# (17.999, 29.0]   17
# (29.0, 39.0]     30
# (39.0, 49.0]     23
# (49.0, 59.0]     11
# (59.0, 69.0]      1

# %%
#ikäluokkien frekvenssiprosentit ja kertymäprosentit
df4 = df['ikä'].value_counts(normalize = True, sort = False, bins = [18,29,39,49,59,69]).to_frame()
df4 = df4.rename(columns = {'ikä': '%'})
df4['kertymä %'] = df4['%'].cumsum()
df4.style.format('{:.1%}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_afe47412_9677_11e8_b660_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >%</th>
#         <th class="col_heading level0 col1" >kertymä %</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_afe47412_9677_11e8_b660_00e18c75b321level0_row0" class="row_heading level0 row0" >(17.999, 29.0]</th>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row0_col0" class="data row0 col0" >20.7%</td>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row0_col1" class="data row0 col1" >20.7%</td>
#     </tr>    <tr>
#         <th id="T_afe47412_9677_11e8_b660_00e18c75b321level0_row1" class="row_heading level0 row1" >(29.0, 39.0]</th>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row1_col0" class="data row1 col0" >36.6%</td>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row1_col1" class="data row1 col1" >57.3%</td>
#     </tr>    <tr>
#         <th id="T_afe47412_9677_11e8_b660_00e18c75b321level0_row2" class="row_heading level0 row2" >(39.0, 49.0]</th>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row2_col0" class="data row2 col0" >28.0%</td>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row2_col1" class="data row2 col1" >85.4%</td>
#     </tr>    <tr>
#         <th id="T_afe47412_9677_11e8_b660_00e18c75b321level0_row3" class="row_heading level0 row3" >(49.0, 59.0]</th>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row3_col0" class="data row3 col0" >13.4%</td>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row3_col1" class="data row3 col1" >98.8%</td>
#     </tr>    <tr>
#         <th id="T_afe47412_9677_11e8_b660_00e18c75b321level0_row4" class="row_heading level0 row4" >(59.0, 69.0]</th>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row4_col0" class="data row4 col0" >1.2%</td>
#         <td id="T_afe47412_9677_11e8_b660_00e18c75b321row4_col1" class="data row4 col1" >100.0%</td>
#     </tr></tbody>
# </table>

# %%
#monivalintakysymyksen valintojen lukumäärät suuruusjärjestyksessä
df5 = df[['työterveyshuolto','lomaosake','kuntosali','hieroja']].sum().sort_values(ascending = False).to_frame()
df5 = df5.rename(columns = {0: 'lkm'})
df5.style.format('{:.0f}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_afe648d4_9677_11e8_80df_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >lkm</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_afe648d4_9677_11e8_80df_00e18c75b321level0_row0" class="row_heading level0 row0" >työterveyshuolto</th>
#         <td id="T_afe648d4_9677_11e8_80df_00e18c75b321row0_col0" class="data row0 col0" >47</td>
#     </tr>    <tr>
#         <th id="T_afe648d4_9677_11e8_80df_00e18c75b321level0_row1" class="row_heading level0 row1" >hieroja</th>
#         <td id="T_afe648d4_9677_11e8_80df_00e18c75b321row1_col0" class="data row1 col0" >22</td>
#     </tr>    <tr>
#         <th id="T_afe648d4_9677_11e8_80df_00e18c75b321level0_row2" class="row_heading level0 row2" >lomaosake</th>
#         <td id="T_afe648d4_9677_11e8_80df_00e18c75b321row2_col0" class="data row2 col0" >20</td>
#     </tr>    <tr>
#         <th id="T_afe648d4_9677_11e8_80df_00e18c75b321level0_row3" class="row_heading level0 row3" >kuntosali</th>
#         <td id="T_afe648d4_9677_11e8_80df_00e18c75b321row3_col0" class="data row3 col0" >9</td>
#     </tr></tbody>
# </table>

# %%
#prosenttia vastaajien kokonaismäärästä
df5['% vastaajista'] = df5['lkm'] / df.shape[0]
df5.style.format({'% vastaajista':'{:.1%}'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_afeb8836_9677_11e8_a490_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >lkm</th>
#         <th class="col_heading level0 col1" >% vastaajista</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_afeb8836_9677_11e8_a490_00e18c75b321level0_row0" class="row_heading level0 row0" >työterveyshuolto</th>
#         <td id="T_afeb8836_9677_11e8_a490_00e18c75b321row0_col0" class="data row0 col0" >47</td>
#         <td id="T_afeb8836_9677_11e8_a490_00e18c75b321row0_col1" class="data row0 col1" >57.3%</td>
#     </tr>    <tr>
#         <th id="T_afeb8836_9677_11e8_a490_00e18c75b321level0_row1" class="row_heading level0 row1" >hieroja</th>
#         <td id="T_afeb8836_9677_11e8_a490_00e18c75b321row1_col0" class="data row1 col0" >22</td>
#         <td id="T_afeb8836_9677_11e8_a490_00e18c75b321row1_col1" class="data row1 col1" >26.8%</td>
#     </tr>    <tr>
#         <th id="T_afeb8836_9677_11e8_a490_00e18c75b321level0_row2" class="row_heading level0 row2" >lomaosake</th>
#         <td id="T_afeb8836_9677_11e8_a490_00e18c75b321row2_col0" class="data row2 col0" >20</td>
#         <td id="T_afeb8836_9677_11e8_a490_00e18c75b321row2_col1" class="data row2 col1" >24.4%</td>
#     </tr>    <tr>
#         <th id="T_afeb8836_9677_11e8_a490_00e18c75b321level0_row3" class="row_heading level0 row3" >kuntosali</th>
#         <td id="T_afeb8836_9677_11e8_a490_00e18c75b321row3_col0" class="data row3 col0" >9</td>
#         <td id="T_afeb8836_9677_11e8_a490_00e18c75b321row3_col1" class="data row3 col1" >11.0%</td>
#     </tr></tbody>
# </table>

# %%
#ristiintaulukointi
df6 = pd.crosstab(df['koulutus'], df['sukupuoli'])
df6.index = ['peruskoulu','2.aste','korkeakoulu','ylempi korkeakoulu']
df6.columns = ['mies','nainen']
df6
# Out:
#                     mies  nainen
# peruskoulu            22       5
# 2.aste                23       7
# korkeakoulu           15       7
# ylempi korkeakoulu     2       0

# %%
#ristiintaulukointi prosentteina
df7 = pd.crosstab(df['koulutus'], df['sukupuoli'], margins = True, normalize = 'columns')
df7.index = ['peruskoulu','2.aste','korkeakoulu','ylempi korkeakoulu']
df7.columns = ['mies','nainen','yhteensä']
df7.style.format('{:.1%}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >mies</th>
#         <th class="col_heading level0 col1" >nainen</th>
#         <th class="col_heading level0 col2" >yhteensä</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321level0_row0" class="row_heading level0 row0" >peruskoulu</th>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row0_col0" class="data row0 col0" >35.5%</td>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row0_col1" class="data row0 col1" >26.3%</td>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row0_col2" class="data row0 col2" >33.3%</td>
#     </tr>    <tr>
#         <th id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321level0_row1" class="row_heading level0 row1" >2.aste</th>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row1_col0" class="data row1 col0" >37.1%</td>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row1_col1" class="data row1 col1" >36.8%</td>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row1_col2" class="data row1 col2" >37.0%</td>
#     </tr>    <tr>
#         <th id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321level0_row2" class="row_heading level0 row2" >korkeakoulu</th>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row2_col0" class="data row2 col0" >24.2%</td>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row2_col1" class="data row2 col1" >36.8%</td>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row2_col2" class="data row2 col2" >27.2%</td>
#     </tr>    <tr>
#         <th id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321level0_row3" class="row_heading level0 row3" >ylempi korkeakoulu</th>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row3_col0" class="data row3 col0" >3.2%</td>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row3_col1" class="data row3 col1" >0.0%</td>
#         <td id="T_aff6fb62_9677_11e8_8cbe_00e18c75b321row3_col2" class="data row3 col2" >2.5%</td>
#     </tr></tbody>
# </table>

# %%
#ikäluokan ja sukupuolen ristiintaulukointi
df['ikäluokka'] = pd.cut(df['ikä'], bins = [18,29,39,49,59,69])
df8 = pd.crosstab(df['ikäluokka'], df['sukupuoli'])
df8.columns = ['mies','nainen']
df8
# Out:
#            mies  nainen
# ikäluokka
# (18, 29]     16       1
# (29, 39]     23       7
# (39, 49]     16       7
# (49, 59]      7       4
# (59, 69]      1       0

# %%
#monivalinnan vaihtoehtojen lukumäärät sukupuolen mukaan
df9 = df.groupby('sukupuoli')['työterveyshuolto','lomaosake','kuntosali','hieroja'].sum()
df9.index = ['mies','nainen']
df9.style.format('{:.0f}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_b00150c6_9677_11e8_9c40_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >työterveyshuolto</th>
#         <th class="col_heading level0 col1" >lomaosake</th>
#         <th class="col_heading level0 col2" >kuntosali</th>
#         <th class="col_heading level0 col3" >hieroja</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b00150c6_9677_11e8_9c40_00e18c75b321level0_row0" class="row_heading level0 row0" >mies</th>
#         <td id="T_b00150c6_9677_11e8_9c40_00e18c75b321row0_col0" class="data row0 col0" >35</td>
#         <td id="T_b00150c6_9677_11e8_9c40_00e18c75b321row0_col1" class="data row0 col1" >16</td>
#         <td id="T_b00150c6_9677_11e8_9c40_00e18c75b321row0_col2" class="data row0 col2" >8</td>
#         <td id="T_b00150c6_9677_11e8_9c40_00e18c75b321row0_col3" class="data row0 col3" >13</td>
#     </tr>    <tr>
#         <th id="T_b00150c6_9677_11e8_9c40_00e18c75b321level0_row1" class="row_heading level0 row1" >nainen</th>
#         <td id="T_b00150c6_9677_11e8_9c40_00e18c75b321row1_col0" class="data row1 col0" >12</td>
#         <td id="T_b00150c6_9677_11e8_9c40_00e18c75b321row1_col1" class="data row1 col1" >4</td>
#         <td id="T_b00150c6_9677_11e8_9c40_00e18c75b321row1_col2" class="data row1 col2" >1</td>
#         <td id="T_b00150c6_9677_11e8_9c40_00e18c75b321row1_col3" class="data row1 col3" >9</td>
#     </tr></tbody>
# </table>

# %%
#prosentit sukupuolesta
df10 = df.groupby('sukupuoli')['työterveyshuolto','lomaosake','kuntosali','hieroja'].sum()
df10.index = ['mies','nainen']
miehet = df['sukupuoli'].value_counts()[1]
naiset = df['sukupuoli'].value_counts()[2]
df10.loc['mies'] = df10.loc['mies'] / miehet
df10.loc['nainen'] = df10.loc['nainen'] / naiset
df10.style.format('{:.1%}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_b003c19c_9677_11e8_a67b_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >työterveyshuolto</th>
#         <th class="col_heading level0 col1" >lomaosake</th>
#         <th class="col_heading level0 col2" >kuntosali</th>
#         <th class="col_heading level0 col3" >hieroja</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b003c19c_9677_11e8_a67b_00e18c75b321level0_row0" class="row_heading level0 row0" >mies</th>
#         <td id="T_b003c19c_9677_11e8_a67b_00e18c75b321row0_col0" class="data row0 col0" >55.6%</td>
#         <td id="T_b003c19c_9677_11e8_a67b_00e18c75b321row0_col1" class="data row0 col1" >25.4%</td>
#         <td id="T_b003c19c_9677_11e8_a67b_00e18c75b321row0_col2" class="data row0 col2" >12.7%</td>
#         <td id="T_b003c19c_9677_11e8_a67b_00e18c75b321row0_col3" class="data row0 col3" >20.6%</td>
#     </tr>    <tr>
#         <th id="T_b003c19c_9677_11e8_a67b_00e18c75b321level0_row1" class="row_heading level0 row1" >nainen</th>
#         <td id="T_b003c19c_9677_11e8_a67b_00e18c75b321row1_col0" class="data row1 col0" >63.2%</td>
#         <td id="T_b003c19c_9677_11e8_a67b_00e18c75b321row1_col1" class="data row1 col1" >21.1%</td>
#         <td id="T_b003c19c_9677_11e8_a67b_00e18c75b321row1_col2" class="data row1 col2" >5.3%</td>
#         <td id="T_b003c19c_9677_11e8_a67b_00e18c75b321row1_col3" class="data row1 col3" >47.4%</td>
#     </tr></tbody>
# </table>

# %%
#koontitaulukko tyytyväisyyksistä
df.rename(columns = {'tyytyväisyys johtoon': 'johtoon', 'tyytyväisyys työtovereihin': 'työtovereihin',
                  'tyytyväisyys työympäristöön': 'työympäristöön', 'tyytyväisyys palkkaan': 'palkkaan',
                  'tyytyväisyys työtehtäviin': 'työtehtäviin'}, inplace = True)
df11=df['johtoon'].value_counts(sort = False).to_frame()
df11['työtovereihin'] = df['työtovereihin'].value_counts(sort = False)
df11['työympäristöön'] = df['työympäristöön'].value_counts(sort = False)
df11['palkkaan'] = df['palkkaan'].value_counts(sort = False)
df11['työtehtäviin'] = df['työtehtäviin'].value_counts(sort = False)
df11.index = ['erittäin tyytymätön','tyytymätön','ei tyytymätön eikä tyytyväinen',
          'tyytyväinen','erittäin tyytyväinen']
df11
# Out:
#                                 johtoon  työtovereihin  työympäristöön  \
# erittäin tyytymätön                   7            NaN               9
# tyytymätön                           16            3.0               9
# ei tyytymätön eikä tyytyväinen       30           16.0              30
# tyytyväinen                          23           35.0              23
# erittäin tyytyväinen                  6           27.0              11
#
#                                 palkkaan  työtehtäviin
# erittäin tyytymätön                   33             5
# tyytymätön                            19            15
# ei tyytymätön eikä tyytyväinen        19            29
# tyytyväinen                           10            25
# erittäin tyytyväinen                   1             8
