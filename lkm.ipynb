# %% [markdown]
# # Lukumääriä ja prosentteja
#
# Parhaat käytännöt lukumäärä- ja prosentti-yhteenvetojen laskemiseen eri tilanteissa.

# %%
import pandas as pd

# %%
#Avaan datan dataframeen.
#Vanhemmissa pandas-versioissa pitää käyttää sheet_name sijasta sheetname.
df = pd.read_excel('http://taanila.fi/data1.xlsx', sheet_name = 'Data')

#Tulostan viisi ensimmäistä riviä:
df.head()
# Out:
#    nro  sukup  ikä  perhe  koulutus  palveluv  palkka  johto  työtov  työymp  \
# 0    1      1   38      1       1.0      22.0    3587      3     3.0       3
# 1    2      1   29      2       2.0      10.0    2963      1     5.0       2
# 2    3      1   30      1       1.0       7.0    1989      3     4.0       1
# 3    4      1   36      2       1.0      14.0    2144      3     3.0       3
# 4    5      1   24      1       2.0       4.0    2183      2     3.0       2
#
#    palkkat  työteht  työterv  lomaosa  kuntosa  hieroja
# 0        3        3      NaN      NaN      NaN      NaN
# 1        1        3      NaN      NaN      NaN      NaN
# 2        1        3      1.0      NaN      NaN      NaN
# 3        3        3      1.0      NaN      NaN      NaN
# 4        1        2      1.0      NaN      NaN      NaN

# %%
#Muutamia listoja jatkoa varten:
koulutus = ['Peruskoulu','2.aste','Korkeakoulu','Ylempi korkeakoulu']
mielipideasteikko = ['Erittäin tyytymätön','Tyytymätön','Neutraali',
          'Tyytyväinen','Erittäin tyytyväinen']
tyytyväisyydet = ['Johtoon','Työtovereihin','Työympäristöön','Palkkaan','Työtehtäviin']
monivalinnat = ['Kuntosali','Lomaosake','Hieroja','Työterveyshuolto']

# %%
#Frekvenssit value_counts-funktiolla:
df1 = df['koulutus'].value_counts(sort = False).to_frame()

#Otsikot kuntoon
df1.index = koulutus

df1
# Out:
#                     koulutus
# Peruskoulu                27
# 2.aste                    30
# Korkeakoulu               22
# Ylempi korkeakoulu         2

# %%
#Prosentit frekvenssien viereen:
df1 = df1.rename(columns = {'koulutus': 'Lkm'})
df1['%'] = df1['Lkm'] / df1['Lkm'].sum() * 100

df1
# Out:
#                     Lkm          %
# Peruskoulu           27  33.333333
# 2.aste               30  37.037037
# Korkeakoulu          22  27.160494
# Ylempi korkeakoulu    2   2.469136

# %%
#Kertymäprosentit ja pyöristys yhteen desimaaliin:
df1['Kertymä-%'] = df1['%'].cumsum().round(decimals = 1)
df1['%'] = df1['%'].round(decimals = 1)

df1
# Out:
#                     Lkm     %  Kertymä-%
# Peruskoulu           27  33.3       33.3
# 2.aste               30  37.0       70.4
# Korkeakoulu          22  27.2       97.5
# Ylempi korkeakoulu    2   2.5      100.0

# %%
#crosstab-funktio on vaihtoehtoinen tapa frekvenssien laskemiseen.
#crosstabin etu on, että se tuottaa suoraan dataframen.
df2 = pd.crosstab(df['koulutus'], 'Lkm')

#Otsikot kuntoon:
df2.index = koulutus
df2.columns.name = '' #poistaa häiritsevän col_0 -otsikon taulukon oikeasta yläkulmasta

df2
# Out:
#                     Lkm
# Peruskoulu           27
# 2.aste               30
# Korkeakoulu          22
# Ylempi korkeakoulu    2

# %%
#Prosentit frekvenssien viereen:
df2['%'] = df2['Lkm'] / df2['Lkm'].sum()*100

df2
# Out:
#                     Lkm          %
# Peruskoulu           27  33.333333
# 2.aste               30  37.037037
# Korkeakoulu          22  27.160494
# Ylempi korkeakoulu    2   2.469136

# %%
#Kertymäprosentit:
df2['Kertymä-%'] = df2['%'].cumsum()

#Loppusilaus:
df2.style.format({'%': '{:.1f} %', 'Kertymä-%': '{:.1f} %'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_84adec70_2eee_11e9_9a3e_00e18c75b321" >
# <thead>    <tr>
#         <th class="index_name level0" ></th>
#         <th class="col_heading level0 col0" >Lkm</th>
#         <th class="col_heading level0 col1" >%</th>
#         <th class="col_heading level0 col2" >Kertymä-%</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_84adec70_2eee_11e9_9a3e_00e18c75b321level0_row0" class="row_heading level0 row0" >Peruskoulu</th>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row0_col0" class="data row0 col0" >27</td>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row0_col1" class="data row0 col1" >33.3 %</td>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row0_col2" class="data row0 col2" >33.3 %</td>
#     </tr>    <tr>
#         <th id="T_84adec70_2eee_11e9_9a3e_00e18c75b321level0_row1" class="row_heading level0 row1" >2.aste</th>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row1_col0" class="data row1 col0" >30</td>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row1_col1" class="data row1 col1" >37.0 %</td>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row1_col2" class="data row1 col2" >70.4 %</td>
#     </tr>    <tr>
#         <th id="T_84adec70_2eee_11e9_9a3e_00e18c75b321level0_row2" class="row_heading level0 row2" >Korkeakoulu</th>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row2_col0" class="data row2 col0" >22</td>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row2_col1" class="data row2 col1" >27.2 %</td>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row2_col2" class="data row2 col2" >97.5 %</td>
#     </tr>    <tr>
#         <th id="T_84adec70_2eee_11e9_9a3e_00e18c75b321level0_row3" class="row_heading level0 row3" >Ylempi korkeakoulu</th>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row3_col0" class="data row3 col0" >2</td>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row3_col1" class="data row3 col1" >2.5 %</td>
#         <td id="T_84adec70_2eee_11e9_9a3e_00e18c75b321row3_col2" class="data row3 col2" >100.0 %</td>
#     </tr></tbody>
# </table>

# %%
#Ikäluokkien frekvenssit:
df3 = df['ikä'].value_counts(sort = False, bins = [18,29,39,49,59,69]).to_frame()

#n-arvo (tarvitsen seuraavassa solussa)
n = df3['ikä'].sum()

df3
# Out:
#                 ikä
# (17.999, 29.0]   17
# (29.0, 39.0]     30
# (39.0, 49.0]     23
# (49.0, 59.0]     11
# (59.0, 69.0]      1

# %%
#Ikäluokkien frekvenssiprosentit ja kertymäprosentit:
df4 = df['ikä'].value_counts(normalize = True, sort = False, bins = [18,29,39,49,59,69]).to_frame() * 100

#Kertymäprosentit:
df4['Kertymä-%'] = df4['ikä'].cumsum()

#Otsikon vaihdos:
df4 = df4.rename(columns = {'ikä':'%, n='+ str(n)})
#df4.columns = ['%' + str(n), 'Kertymä-%']

#Loppusilaus
df4.style.format('{:.1f} %')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >%, n=82</th>
#         <th class="col_heading level0 col1" >Kertymä-%</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321level0_row0" class="row_heading level0 row0" >(17.999, 29.0]</th>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row0_col0" class="data row0 col0" >20.7 %</td>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row0_col1" class="data row0 col1" >20.7 %</td>
#     </tr>    <tr>
#         <th id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321level0_row1" class="row_heading level0 row1" >(29.0, 39.0]</th>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row1_col0" class="data row1 col0" >36.6 %</td>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row1_col1" class="data row1 col1" >57.3 %</td>
#     </tr>    <tr>
#         <th id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321level0_row2" class="row_heading level0 row2" >(39.0, 49.0]</th>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row2_col0" class="data row2 col0" >28.0 %</td>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row2_col1" class="data row2 col1" >85.4 %</td>
#     </tr>    <tr>
#         <th id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321level0_row3" class="row_heading level0 row3" >(49.0, 59.0]</th>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row3_col0" class="data row3 col0" >13.4 %</td>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row3_col1" class="data row3 col1" >98.8 %</td>
#     </tr>    <tr>
#         <th id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321level0_row4" class="row_heading level0 row4" >(59.0, 69.0]</th>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row4_col0" class="data row4 col0" >1.2 %</td>
#         <td id="T_84b3c6c0_2eee_11e9_bfd9_00e18c75b321row4_col1" class="data row4 col1" >100.0 %</td>
#     </tr></tbody>
# </table>

# %%
#Monivalintakysymyksen valintojen lukumäärät suuruusjärjestyksessä:
df5 = df[['työterv','lomaosa','kuntosa','hieroja']].sum().sort_values(ascending = False).to_frame()

#Otsikot kuntoon:
df5 = df5.rename(columns = {0: 'Lkm'})
df5.index=monivalinnat

#Loppusilaus:
df5.style.format('{:.0f}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_84b636ec_2eee_11e9_9dc7_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Lkm</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_84b636ec_2eee_11e9_9dc7_00e18c75b321level0_row0" class="row_heading level0 row0" >Kuntosali</th>
#         <td id="T_84b636ec_2eee_11e9_9dc7_00e18c75b321row0_col0" class="data row0 col0" >47</td>
#     </tr>    <tr>
#         <th id="T_84b636ec_2eee_11e9_9dc7_00e18c75b321level0_row1" class="row_heading level0 row1" >Lomaosake</th>
#         <td id="T_84b636ec_2eee_11e9_9dc7_00e18c75b321row1_col0" class="data row1 col0" >22</td>
#     </tr>    <tr>
#         <th id="T_84b636ec_2eee_11e9_9dc7_00e18c75b321level0_row2" class="row_heading level0 row2" >Hieroja</th>
#         <td id="T_84b636ec_2eee_11e9_9dc7_00e18c75b321row2_col0" class="data row2 col0" >20</td>
#     </tr>    <tr>
#         <th id="T_84b636ec_2eee_11e9_9dc7_00e18c75b321level0_row3" class="row_heading level0 row3" >Työterveyshuolto</th>
#         <td id="T_84b636ec_2eee_11e9_9dc7_00e18c75b321row3_col0" class="data row3 col0" >9</td>
#     </tr></tbody>
# </table>

# %%
#Prosenttia vastaajien kokonaismäärästä:
df5['% vastaajista'] = df5['Lkm'] / df.shape[0] *100

#Loppusilaus:
df5.style.format({'% vastaajista':'{:.1f} %'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_84b80b14_2eee_11e9_bedd_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Lkm</th>
#         <th class="col_heading level0 col1" >% vastaajista</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_84b80b14_2eee_11e9_bedd_00e18c75b321level0_row0" class="row_heading level0 row0" >Kuntosali</th>
#         <td id="T_84b80b14_2eee_11e9_bedd_00e18c75b321row0_col0" class="data row0 col0" >47</td>
#         <td id="T_84b80b14_2eee_11e9_bedd_00e18c75b321row0_col1" class="data row0 col1" >57.3 %</td>
#     </tr>    <tr>
#         <th id="T_84b80b14_2eee_11e9_bedd_00e18c75b321level0_row1" class="row_heading level0 row1" >Lomaosake</th>
#         <td id="T_84b80b14_2eee_11e9_bedd_00e18c75b321row1_col0" class="data row1 col0" >22</td>
#         <td id="T_84b80b14_2eee_11e9_bedd_00e18c75b321row1_col1" class="data row1 col1" >26.8 %</td>
#     </tr>    <tr>
#         <th id="T_84b80b14_2eee_11e9_bedd_00e18c75b321level0_row2" class="row_heading level0 row2" >Hieroja</th>
#         <td id="T_84b80b14_2eee_11e9_bedd_00e18c75b321row2_col0" class="data row2 col0" >20</td>
#         <td id="T_84b80b14_2eee_11e9_bedd_00e18c75b321row2_col1" class="data row2 col1" >24.4 %</td>
#     </tr>    <tr>
#         <th id="T_84b80b14_2eee_11e9_bedd_00e18c75b321level0_row3" class="row_heading level0 row3" >Työterveyshuolto</th>
#         <td id="T_84b80b14_2eee_11e9_bedd_00e18c75b321row3_col0" class="data row3 col0" >9</td>
#         <td id="T_84b80b14_2eee_11e9_bedd_00e18c75b321row3_col1" class="data row3 col1" >11.0 %</td>
#     </tr></tbody>
# </table>

# %%
#Ristiintaulukointi:
df6 = pd.crosstab(df['koulutus'], df['sukup'])

#Otsikot kuntoon:
df6.index = koulutus
df6.columns = ['Mies','Nainen']

#Miesten ja naisten lukumäärät (tarvitsen seuraavassa solussa):
miehet = df6['Mies'].sum()
naiset = df6['Nainen'].sum()

df6
# Out:
#                     Mies  Nainen
# Peruskoulu            22       5
# 2.aste                23       7
# Korkeakoulu           15       7
# Ylempi korkeakoulu     2       0

# %%
#Ristiintaulukointi prosentteina:
df7 = pd.crosstab(df['koulutus'], df['sukup'], margins = True, normalize = 'columns') * 100

#Otsikot kuntoon:
df7.index = koulutus

#Kikkaillaan n-arvot mukaan:
df7.columns = ['Mies, n=' + str(miehet),'Nainen, n=' + str(naiset),
               'Yhteensä, n=' + str(miehet+naiset)]

#Loppusilaus:
df7.style.format('{:.1f} %')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Mies, n=62</th>
#         <th class="col_heading level0 col1" >Nainen, n=19</th>
#         <th class="col_heading level0 col2" >Yhteensä, n=81</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321level0_row0" class="row_heading level0 row0" >Peruskoulu</th>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row0_col0" class="data row0 col0" >35.5 %</td>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row0_col1" class="data row0 col1" >26.3 %</td>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row0_col2" class="data row0 col2" >33.3 %</td>
#     </tr>    <tr>
#         <th id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321level0_row1" class="row_heading level0 row1" >2.aste</th>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row1_col0" class="data row1 col0" >37.1 %</td>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row1_col1" class="data row1 col1" >36.8 %</td>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row1_col2" class="data row1 col2" >37.0 %</td>
#     </tr>    <tr>
#         <th id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321level0_row2" class="row_heading level0 row2" >Korkeakoulu</th>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row2_col0" class="data row2 col0" >24.2 %</td>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row2_col1" class="data row2 col1" >36.8 %</td>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row2_col2" class="data row2 col2" >27.2 %</td>
#     </tr>    <tr>
#         <th id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321level0_row3" class="row_heading level0 row3" >Ylempi korkeakoulu</th>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row3_col0" class="data row3 col0" >3.2 %</td>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row3_col1" class="data row3 col1" >0.0 %</td>
#         <td id="T_84c1cbb0_2eee_11e9_a33f_00e18c75b321row3_col2" class="data row3 col2" >2.5 %</td>
#     </tr></tbody>
# </table>

# %%
#Ikäluokan ja sukupuolen ristiintaulukointi:
df['ikäluokka'] = pd.cut(df['ikä'], bins = [18,29,39,49,59,69])
df8 = pd.crosstab(df['ikäluokka'], df['sukup'])

#Otsikot kuntoon:
df8.columns = ['Mies','Nainen']
df8.index.name='Ikäluokka'

df8
# Out:
#            Mies  Nainen
# Ikäluokka
# (18, 29]     16       1
# (29, 39]     23       7
# (39, 49]     16       7
# (49, 59]      7       4
# (59, 69]      1       0

# %%
#Monivalinnan vaihtoehtojen lukumäärät sukupuolen mukaan:
df9 = df.groupby('sukup')['työterv','lomaosa','kuntosa','hieroja'].sum()

#Otsikot kuntoon:
df9.index = ['Mies','Nainen']
df9.columns = monivalinnat

#Loppusilaus:
df9.style.format('{:.0f}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Kuntosali</th>
#         <th class="col_heading level0 col1" >Lomaosake</th>
#         <th class="col_heading level0 col2" >Hieroja</th>
#         <th class="col_heading level0 col3" >Työterveyshuolto</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321level0_row0" class="row_heading level0 row0" >Mies</th>
#         <td id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321row0_col0" class="data row0 col0" >35</td>
#         <td id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321row0_col1" class="data row0 col1" >16</td>
#         <td id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321row0_col2" class="data row0 col2" >8</td>
#         <td id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321row0_col3" class="data row0 col3" >13</td>
#     </tr>    <tr>
#         <th id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321level0_row1" class="row_heading level0 row1" >Nainen</th>
#         <td id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321row1_col0" class="data row1 col0" >12</td>
#         <td id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321row1_col1" class="data row1 col1" >4</td>
#         <td id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321row1_col2" class="data row1 col2" >1</td>
#         <td id="T_84ca544a_2eee_11e9_a4fb_00e18c75b321row1_col3" class="data row1 col3" >9</td>
#     </tr></tbody>
# </table>

# %%
#Prosentit sukupuolesta:
df10 = df.groupby('sukup')['työterv','lomaosa','kuntosa','hieroja'].sum() * 100

#Otsikot kuntoon:
df10.index = ['Mies','Nainen']
df10.columns = monivalinnat

#Miesten ja naisten lukumäärät:
miehet = df['sukup'].value_counts()[1]
naiset = df['sukup'].value_counts()[2]

#Prosentit:
df10.iloc[0] = df10.iloc[0] / miehet
df10.iloc[1] = df10.iloc[1] / naiset

#Kikkaillaan n-arvot mukaan:
df10.index = ['Mies, n=' + str(miehet) ,'Nainen, n=' + str(naiset)]

#Loppusilaus:
df10.style.format('{:.1f} %')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_84ccc478_2eee_11e9_a57e_00e18c75b321" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Kuntosali</th>
#         <th class="col_heading level0 col1" >Lomaosake</th>
#         <th class="col_heading level0 col2" >Hieroja</th>
#         <th class="col_heading level0 col3" >Työterveyshuolto</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_84ccc478_2eee_11e9_a57e_00e18c75b321level0_row0" class="row_heading level0 row0" >Mies, n=63</th>
#         <td id="T_84ccc478_2eee_11e9_a57e_00e18c75b321row0_col0" class="data row0 col0" >55.6 %</td>
#         <td id="T_84ccc478_2eee_11e9_a57e_00e18c75b321row0_col1" class="data row0 col1" >25.4 %</td>
#         <td id="T_84ccc478_2eee_11e9_a57e_00e18c75b321row0_col2" class="data row0 col2" >12.7 %</td>
#         <td id="T_84ccc478_2eee_11e9_a57e_00e18c75b321row0_col3" class="data row0 col3" >20.6 %</td>
#     </tr>    <tr>
#         <th id="T_84ccc478_2eee_11e9_a57e_00e18c75b321level0_row1" class="row_heading level0 row1" >Nainen, n=19</th>
#         <td id="T_84ccc478_2eee_11e9_a57e_00e18c75b321row1_col0" class="data row1 col0" >63.2 %</td>
#         <td id="T_84ccc478_2eee_11e9_a57e_00e18c75b321row1_col1" class="data row1 col1" >21.1 %</td>
#         <td id="T_84ccc478_2eee_11e9_a57e_00e18c75b321row1_col2" class="data row1 col2" >5.3 %</td>
#         <td id="T_84ccc478_2eee_11e9_a57e_00e18c75b321row1_col3" class="data row1 col3" >47.4 %</td>
#     </tr></tbody>
# </table>
